# %%
#WA21
print("Hello World!")
# Out:
# Hello World!

# %%
#W2A2
x=input("Nhap vao ten nguoi dung: ")
print("Xin chao ", x)
# Out:
# Xin chao  Manh Tuan

# %%
#W2A3
a, b = map(int, input("nhap vao 2 so a va b: ").split())
tong = a+b
hieu = a-b
tich = a*b
pnguyen = a/b
pdu = a%b
kq = a/b
print( tong, "\n", hieu, "\n", tich, "\n", pnguyen, "\n", pdu, "\n", round(kq, 2), "\n")
# Out:
# 17
#  -3
#  70
#  0.7
#  7
#  0.7

# %%
#W2A4
a1,b1,c1,a2,b2,a3 = map(float, input("nhap: ").split())
tb=(a1+b1+c1+(a2+b2)*2+(a3*3))/10
print("Diem : ", round(tb, 1))
# Out:
# Diem :  8.2

# %%
#W2A5
a, b = map(int, input("nhap vao 2 so a va b: ").split())
print(a**b)
# Out:
# 282475249

# %%
#W2A6
kt=str(input("Nhap vao 1 ki tu: "))
if 'a' <= kt <= 'z':
    print(ord(kt))
    print("ki tu hoa la: ", kt.upper())
# Out:
# 116
# ki tu hoa la:  T

# %%
#W2A7
A=((13**2)*3)+5
B=13**2*3+5
print(A, "\n", B, "\n")
# Out:
# 512
#  512

# %%
#W2A8
c=int(input("nhap vao do C: "))
f=9/5*c+32
print("do F tuong duong la: ", round(f, 2))
# Out:
# do F tuong duong la:  98.6

# %%
#W2A9
x=float(input("Nhap gia cai dong ho: "))
xm=(x+10)*1.4
print("phai tra chinh xac: ", round(xm, 2))
# Out:
# phai tra chinh xac:  994.0

# %%
#W2A10
x1, x2, x3 = map(str, input("Nhap vao ten 3 nguoi: ").split())
print("Hi", x3, x2, "and", x1)
# Out:
# Hi Helen Alice and Bob

# %%
#W2A11
h, m =map(int, input("Nhap vao so gio va so phut: ").split())
print(h*60*60, "\n", m*60, "\n")
# Out:
# 7200
#  3000

# %%
#W2A12
n = int(input("Nhập cạnh n: "))
so = 6 * n * n
print("Số miếng dán cần dùng:", so)
# Out:
# Số miếng dán cần dùng: 24

# %%
#W2A13
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))
dvi= (a * b) % 10
print("Hàng đơn vị của tích a*b là:", dvi)
# Out:
# Hàng đơn vị của tích a*b là: 0

# %%
#W2A14
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))
a = a + b
b = a - b
a = a - b
print("Sau khi hoán đổi:")
print("a =", a)
print("b =", b)
# Out:
# Sau khi hoán đổi:
# a = 10
# b = 7

# %%
#W2A15
n = int(input("Nhập n: "))
sao = 3 * n * (n - 1) + 1
print("Số sao thứ", n, "là:", sao)
# Out:
# Số sao thứ 5 là: 61

# %%
#W2A16
print("Spring\nSummer\nAutumn\nWinter\n")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
print("*\n**\n***\n")
# Out:
# *
# **
# ***

# %%
#W2A18
print("# # #  # # #   # # # # # #")
print("  #    #    #    #     #")
print("  #    #     #   #     #")
print("  #    #    #    #     #")
print("  #    # #       #     #")
# Out:
# # # #  # # #   # # # # # #
#   #    #    #    #     #
#   #    #     #   #     #
#   #    #    #    #     #
#   #    # #       #     #

# %%
#W2A19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday\n")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAuguts\nSeptermber\nOctober\nNovember\nDecember\n")
# Out:
# January
# February
# March
# April
# May
# June
# July
# Auguts
# Septermber
# October
# November
# December

# %%
#W2A21
for i in range(1,11):
    if i<=10:
        print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
