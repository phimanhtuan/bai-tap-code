# %%
#W3A2
a=6
b=3
a=a^b
b=a^b
a=a^b
print("a=", a)
print("b=", b)
# Out:
# a= 3
# b= 6

# %%
#W3A4
m=int(input("nhap 1 so: "))
n=int(input("nhap 1 so: "))
x=m/n
print(round(x))
# Out:
# 3

# %%
#W3A5
m=int(input("nhap 1 so: "))
n=int(input("nhap 1 so: "))
if m%n!=0:
    x_=(m+n)/n
    print(round(x_))
# Out:
# 4

# %%
#W3A6
x=int(input("Nhap vao 2 so: "))
if x >0:
    if x%2==0:
        print("even")
    else:
        print("odd")
else:
    print("nhap lai so")
# Out:
# even

# %%
#W3A7
a, b = map(int, input("Nhap vao 2 so: ").split())
if a<0 and b<0:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
#W3A8
a, b = map(str, input("Nhap vao 2 chuoi: ").split())
if len(a) > len(b):
    print("True")
else:
    print("No")
# Out:
# True

# %%
#W3A10
a, b, c, d = map(int , input("Nhap vao 4 so").split())
x=max(a, b, c, d)
print(x)
# Out:
# 10

# %%
#W3A16
x=float(input("Nhap vao 1 so thuc: "))
#7,1-> 8 7 7
x1=int(x)+1
x2=int(x)
if x-int(x)>5:
    x3=int(x)+1
else:
    x3=int(x)
print(x1, x2, x3, sep=" ")
# Out:
# 8 7 7

# %%
#W3A17
a, b, c, d = map(int, input().split())
if b % a == 0:
    r = b // a
    if b * r == c and c * r == d:
        print("YES")
    else:
        print("NO")
else:
    print("NO")
# Out:
# NO
